# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical
import gym #pip install box2d box2d-kengz --user #openAI

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Memory:#训练数据收集
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []#是否终止
    
    def clear_memory(self):
        del self.actions[:] # [:] Deletes all the elements in the array
        del self.states[:]  
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, n_latent_var):
        super(ActorCritic, self).__init__()

        # actor 输入一个state 决定一个action
        self.action_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),#state是一个8维度向量
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, action_dim),#action_dim=4，上下左右挑一个
                nn.Softmax(dim=-1) #dim=-1 得到四个概率值
                )
        
        # critic 级别越高打越厉害的怪，actor 做完了一个动作，到底可取不可取
        self.value_layer = nn.Sequential(
                nn.Linear(state_dim, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, n_latent_var),
                nn.Tanh(),
                nn.Linear(n_latent_var, 1)#PPO2策略,最后返回一个value，用这个value state确定这个动作可取还是不可取（R-V）
                )
        
    def forward(self):
        raise NotImplementedError
        
    def act(self, state, memory):
        state = torch.from_numpy(state).float().to(device)#游戏环境拿到手的，送入gpu
        action_probs = self.action_layer(state)##就是那个actor 得到四个概率值
        dist = Categorical(action_probs)#按照给定的概率分布来进行采样
        #作用是创建以参数probs为标准的类别分布，样本是来自 “0 … K-1” 的整数，其中 K 是probs参数的长度。
        #也就是说，按照传入的probs中给定的概率，在
        #相应的位置处进行取样，取样返回的是该位置的整数索引。
        action = dist.sample()# 根据现有分布抽样
        
        memory.states.append(state)#用list存起来
        memory.actions.append(action)
        memory.logprobs.append(dist.log_prob(action))
        
        return action.item()
    
    def evaluate(self, state, action):
        action_probs = self.action_layer(state)
        dist = Categorical(action_probs)
        
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        
        state_value = self.value_layer(state)
        
        return action_logprobs, torch.squeeze(state_value), dist_entropy

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = ActorCritic(state_dim, action_dim, n_latent_var).to(device)#构建两个网络模型
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr, betas=betas)
        self.policy_old = ActorCritic(state_dim, action_dim, n_latent_var).to(device)#实际与环境交互取参数的狸猫
        self.policy_old.load_state_dict(self.policy.state_dict())#在第一局一模一样，初始化时候一模一样
        
        self.MseLoss = nn.MSELoss()
    
    def update(self, memory):   
        # Monte Carlo estimate of state rewards:
        #对后续的印象打折
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)#gamma就是折扣，0.99很小
            rewards.insert(0, discounted_reward)
        
        # Normalizing the rewards:
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-5)
        
        # convert list to tensor
        old_states = torch.stack(memory.states).to(device).detach()#2000个
        old_actions = torch.stack(memory.actions).to(device).detach()
        old_logprobs = torch.stack(memory.logprobs).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):#用以上的数据更新K_epochs 四次
            # Evaluating old actions and values :
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)#过去的acttion 走一遍
            
            # Finding the ratio (pi_theta / pi_theta__old):
            #由于是对数改成减法
            ratios = torch.exp(logprobs - old_logprobs.detach())
                
            # Finding Surrogate Loss:就是ppo2公式的实现
            advantages = rewards - state_values.detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip) * advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy#td差分先不管了
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        
        # Copy new weights into old policy:
        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
def main():
    ############## Hyperparameters ##############
    env_name = "LunarLander-v2" ##游戏名称
    # creating environment
    env = gym.make(env_name)## 导入游戏
    state_dim = env.observation_space.shape[0]# 走一个action 得到一个state,这个state是一个8维度向量
    action_dim = 4 #上下左右
    render = True              # 是不是显示游戏过程
    solved_reward = 230         # stop training if avg_reward > solved_reward 
    log_interval = 20           # print avg reward in the interval
    max_episodes = 50000        # max training episodes
    max_timesteps = 300         # max timesteps in one episode
    n_latent_var = 64           # number of variables in hidden layer
    update_timestep = 2000      # update policy every n timesteps 多少个timestep之后供当前theta学习
    lr = 0.002
    betas = (0.9, 0.999)        #一阶二阶中心距更新权重参数
    gamma = 0.99                # discount factor
    K_epochs = 4                # update policy for K epochs 用狸猫取来的数据现在自己学多少次
    eps_clip = 0.2              # clip parameter for PPO
    random_seed = None
    #############################################
    
    if random_seed:
        torch.manual_seed(random_seed)
        env.seed(random_seed)
    
    memory = Memory()#训练数据收集，其实是玩了很多次游戏然后收集了才开始用
    ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)
    #print(lr,betas)
    
    # logging variables
    running_reward = 0
    avg_length = 0
    timestep = 0
    
    # training loop
    for i_episode in range(1, max_episodes+1):#最多游戏次数
        state = env.reset()#初始化（重新玩）
        for t in range(max_timesteps):#避免无限循环，三百个行为就完事
            timestep += 1
            
            # Running policy_old:
            action = ppo.policy_old.act(state, memory)## 用police old（狸猫）产生数据
            state, reward, done, _ = env.step(action)#得到（新的状态，奖励，是否终止，额外的调试信息）
            
            # Saving reward and is_terminal:
            memory.rewards.append(reward)
            memory.is_terminals.append(done)
            
            # update if its time
            if timestep % update_timestep == 0:
                ppo.update(memory)#2000个更新一次数据
                memory.clear_memory()
                timestep = 0
            
            running_reward += reward
            if render:
                env.render()
            if done:
                break
                
        avg_length += t
        
        # stop training if avg_reward > solved_reward
        if running_reward > (log_interval*solved_reward):
            print("########## Solved! ##########")
            torch.save(ppo.policy.state_dict(), './PPO_{}.pth'.format(env_name))
            break
            
        # logging
        if i_episode % log_interval == 0:
            avg_length = int(avg_length/log_interval)
            running_reward = int((running_reward/log_interval))
            
            print('Episode {} \t avg length: {} \t reward: {}'.format(i_episode, avg_length, running_reward))
            running_reward = 0
            avg_length = 0

# %%
if __name__ == '__main__':
    main()
# Out:
# Episode 20 	 avg length: 89 	 reward: -184
# Episode 40 	 avg length: 91 	 reward: -193
# Episode 60 	 avg length: 105 	 reward: -213
# Episode 80 	 avg length: 103 	 reward: -165
# Episode 100 	 avg length: 97 	 reward: -117
# Episode 120 	 avg length: 96 	 reward: -133
# Episode 140 	 avg length: 89 	 reward: -137
# Episode 160 	 avg length: 90 	 reward: -166
# Episode 180 	 avg length: 95 	 reward: -203
# Episode 200 	 avg length: 88 	 reward: -174
# Episode 220 	 avg length: 84 	 reward: -122
# Episode 240 	 avg length: 100 	 reward: -130
# Episode 260 	 avg length: 91 	 reward: -125
# Episode 280 	 avg length: 85 	 reward: -138
# Episode 300 	 avg length: 88 	 reward: -143
# Episode 320 	 avg length: 92 	 reward: -120
# Episode 340 	 avg length: 99 	 reward: -127
# Episode 360 	 avg length: 92 	 reward: -125
# Episode 380 	 avg length: 87 	 reward: -116
# Episode 400 	 avg length: 79 	 reward: -103
# Episode 420 	 avg length: 79 	 reward: -101
# Episode 440 	 avg length: 91 	 reward: -103
# Episode 460 	 avg length: 93 	 reward: -101
# Episode 480 	 avg length: 101 	 reward: -77
# Episode 500 	 avg length: 109 	 reward: -130
# Episode 520 	 avg length: 118 	 reward: -111
# Episode 540 	 avg length: 119 	 reward: -58
# Episode 560 	 avg length: 185 	 reward: -71
# Episode 580 	 avg length: 218 	 reward: -27
# Episode 600 	 avg length: 221 	 reward: 22
# Episode 620 	 avg length: 166 	 reward: 0
# Episode 640 	 avg length: 179 	 reward: 12
# Episode 660 	 avg length: 215 	 reward: 30
# Episode 680 	 avg length: 255 	 reward: 32
# Episode 700 	 avg length: 274 	 reward: 39
# Episode 720 	 avg length: 299 	 reward: 73
# Episode 740 	 avg length: 240 	 reward: 71
# Episode 760 	 avg length: 214 	 reward: 58
# Episode 780 	 avg length: 199 	 reward: 48
# Episode 800 	 avg length: 249 	 reward: 74
# Episode 820 	 avg length: 208 	 reward: 55
# Episode 840 	 avg length: 209 	 reward: 68
# Episode 860 	 avg length: 243 	 reward: 88
# Episode 880 	 avg length: 289 	 reward: 92
# Episode 900 	 avg length: 275 	 reward: 85
# Episode 920 	 avg length: 262 	 reward: 91
# Episode 940 	 avg length: 256 	 reward: 94
# Episode 960 	 avg length: 262 	 reward: 81
# Episode 980 	 avg length: 228 	 reward: 73
# Episode 1000 	 avg length: 273 	 reward: 85
# Episode 1020 	 avg length: 294 	 reward: 90
# Episode 1040 	 avg length: 284 	 reward: 108
# Episode 1060 	 avg length: 267 	 reward: 105
# Episode 1080 	 avg length: 212 	 reward: 79
# Episode 1100 	 avg length: 238 	 reward: 88
# Episode 1120 	 avg length: 221 	 reward: 66
# Episode 1140 	 avg length: 243 	 reward: 88
# Episode 1160 	 avg length: 233 	 reward: 68
# Episode 1180 	 avg length: 264 	 reward: 91
# Episode 1200 	 avg length: 279 	 reward: 122
# Episode 1220 	 avg length: 273 	 reward: 117
# Episode 1240 	 avg length: 259 	 reward: 98
# Episode 1260 	 avg length: 266 	 reward: 110
# Episode 1280 	 avg length: 230 	 reward: 70
# Episode 1300 	 avg length: 265 	 reward: 105
# Episode 1320 	 avg length: 299 	 reward: 139
# Episode 1340 	 avg length: 272 	 reward: 118
# Episode 1360 	 avg length: 280 	 reward: 117
# Episode 1380 	 avg length: 280 	 reward: 124
# Episode 1400 	 avg length: 246 	 reward: 108
# Episode 1420 	 avg length: 254 	 reward: 80
# Episode 1440 	 avg length: 259 	 reward: 112
# Episode 1460 	 avg length: 293 	 reward: 136
# Episode 1480 	 avg length: 256 	 reward: 115
# Episode 1500 	 avg length: 284 	 reward: 139
# Episode 1520 	 avg length: 261 	 reward: 145
# Episode 1540 	 avg length: 220 	 reward: 90
# Episode 1560 	 avg length: 257 	 reward: 128
# Episode 1580 	 avg length: 250 	 reward: 126
# Episode 1600 	 avg length: 217 	 reward: 93
# Episode 1620 	 avg length: 261 	 reward: 143
# Episode 1640 	 avg length: 286 	 reward: 135
# Episode 1660 	 avg length: 264 	 reward: 124
# Episode 1680 	 avg length: 252 	 reward: 131
# Episode 1700 	 avg length: 227 	 reward: 98
# Episode 1720 	 avg length: 266 	 reward: 133
# Episode 1740 	 avg length: 274 	 reward: 135
# Episode 1760 	 avg length: 261 	 reward: 123
# Episode 1780 	 avg length: 205 	 reward: 77
# Episode 1800 	 avg length: 211 	 reward: 94
# Episode 1820 	 avg length: 223 	 reward: 110
# Episode 1840 	 avg length: 275 	 reward: 119
# Episode 1860 	 avg length: 264 	 reward: 139
# Episode 1880 	 avg length: 253 	 reward: 131
# Episode 1900 	 avg length: 272 	 reward: 130
# Episode 1920 	 avg length: 284 	 reward: 140
# Episode 1940 	 avg length: 277 	 reward: 146
# Episode 1960 	 avg length: 207 	 reward: 102
# Episode 1980 	 avg length: 262 	 reward: 149
# Episode 2000 	 avg length: 266 	 reward: 134
# Episode 2020 	 avg length: 239 	 reward: 123
# Episode 2040 	 avg length: 255 	 reward: 133
# Episode 2060 	 avg length: 252 	 reward: 148
# Episode 2080 	 avg length: 281 	 reward: 147
# Episode 2100 	 avg length: 234 	 reward: 118
# Episode 2120 	 avg length: 289 	 reward: 171
# Episode 2140 	 avg length: 287 	 reward: 156
# Episode 2160 	 avg length: 273 	 reward: 157
# Episode 2180 	 avg length: 249 	 reward: 110
# Episode 2200 	 avg length: 258 	 reward: 103
# Episode 2220 	 avg length: 239 	 reward: 85
# Episode 2240 	 avg length: 233 	 reward: 116
# Episode 2260 	 avg length: 267 	 reward: 125
# Episode 2280 	 avg length: 268 	 reward: 160
# Episode 2300 	 avg length: 259 	 reward: 152
# Episode 2320 	 avg length: 248 	 reward: 131
# Episode 2340 	 avg length: 262 	 reward: 163
# Episode 2360 	 avg length: 275 	 reward: 154
# Episode 2380 	 avg length: 267 	 reward: 144
# Episode 2400 	 avg length: 293 	 reward: 162
# Episode 2420 	 avg length: 276 	 reward: 152
# Episode 2440 	 avg length: 277 	 reward: 143
# Episode 2460 	 avg length: 283 	 reward: 171
# Episode 2480 	 avg length: 270 	 reward: 149
# Episode 2500 	 avg length: 264 	 reward: 140
# Episode 2520 	 avg length: 269 	 reward: 146
# Episode 2540 	 avg length: 278 	 reward: 148
# Episode 2560 	 avg length: 255 	 reward: 126
# Episode 2580 	 avg length: 234 	 reward: 124
# Episode 2600 	 avg length: 217 	 reward: 98
# Episode 2620 	 avg length: 244 	 reward: 116
# Episode 2640 	 avg length: 251 	 reward: 124
# Episode 2660 	 avg length: 251 	 reward: 138
# Episode 2680 	 avg length: 264 	 reward: 133
# Episode 2700 	 avg length: 256 	 reward: 139
# Episode 2720 	 avg length: 264 	 reward: 140
# Episode 2740 	 avg length: 238 	 reward: 117
# Episode 2760 	 avg length: 289 	 reward: 174
# Episode 2780 	 avg length: 257 	 reward: 135
# Episode 2800 	 avg length: 283 	 reward: 161
# Episode 2820 	 avg length: 242 	 reward: 125
# Episode 2840 	 avg length: 246 	 reward: 125
# Episode 2860 	 avg length: 234 	 reward: 118
# Episode 2880 	 avg length: 272 	 reward: 146
# Episode 2900 	 avg length: 273 	 reward: 146
# Episode 2920 	 avg length: 213 	 reward: 95
# Episode 2940 	 avg length: 234 	 reward: 111
# Episode 2960 	 avg length: 203 	 reward: 109
# Episode 2980 	 avg length: 242 	 reward: 126
# Episode 3000 	 avg length: 253 	 reward: 143
# Episode 3020 	 avg length: 218 	 reward: 113
# Episode 3040 	 avg length: 197 	 reward: 86
# Episode 3060 	 avg length: 247 	 reward: 126
# Episode 3080 	 avg length: 255 	 reward: 151
# Episode 3100 	 avg length: 235 	 reward: 108
# Episode 3120 	 avg length: 290 	 reward: 153
# Episode 3140 	 avg length: 249 	 reward: 125
# Episode 3160 	 avg length: 259 	 reward: 141
# Episode 3180 	 avg length: 263 	 reward: 155
# Episode 3200 	 avg length: 265 	 reward: 132
# Episode 3220 	 avg length: 226 	 reward: 113
# Episode 3240 	 avg length: 245 	 reward: 123
# Episode 3260 	 avg length: 255 	 reward: 131
# Episode 3280 	 avg length: 243 	 reward: 118
# Episode 3300 	 avg length: 239 	 reward: 130
# Episode 3320 	 avg length: 297 	 reward: 163
# Episode 3340 	 avg length: 252 	 reward: 119
# Episode 3360 	 avg length: 285 	 reward: 150
# Episode 3380 	 avg length: 231 	 reward: 119
# Episode 3400 	 avg length: 248 	 reward: 119
# Episode 3420 	 avg length: 238 	 reward: 113
# Episode 3440 	 avg length: 264 	 reward: 128
# Episode 3460 	 avg length: 299 	 reward: 162
# Episode 3480 	 avg length: 274 	 reward: 135
# Episode 3500 	 avg length: 258 	 reward: 130
# Episode 3520 	 avg length: 278 	 reward: 153
# Episode 3540 	 avg length: 274 	 reward: 131
# Episode 3560 	 avg length: 252 	 reward: 135
# Episode 3580 	 avg length: 266 	 reward: 146
# Episode 3600 	 avg length: 271 	 reward: 146
# Episode 3620 	 avg length: 277 	 reward: 160
# Episode 3640 	 avg length: 265 	 reward: 144
# Episode 3660 	 avg length: 273 	 reward: 146
# Episode 3680 	 avg length: 267 	 reward: 157
# Episode 3700 	 avg length: 287 	 reward: 164
# Episode 3720 	 avg length: 284 	 reward: 155
# Episode 3740 	 avg length: 299 	 reward: 165
# Episode 3760 	 avg length: 279 	 reward: 146
# Episode 3780 	 avg length: 275 	 reward: 148
# Episode 3800 	 avg length: 275 	 reward: 146
# Episode 3820 	 avg length: 254 	 reward: 146
# Episode 3840 	 avg length: 273 	 reward: 142
# Episode 3860 	 avg length: 264 	 reward: 134
# Episode 3880 	 avg length: 265 	 reward: 149
# Episode 3900 	 avg length: 294 	 reward: 162
# Episode 3920 	 avg length: 248 	 reward: 121
# Episode 3940 	 avg length: 278 	 reward: 157
# Episode 3960 	 avg length: 284 	 reward: 158
# Episode 3980 	 avg length: 287 	 reward: 158
# Episode 4000 	 avg length: 273 	 reward: 146
# Episode 4020 	 avg length: 282 	 reward: 159
# Episode 4040 	 avg length: 269 	 reward: 164
# Episode 4060 	 avg length: 266 	 reward: 133
# Episode 4080 	 avg length: 292 	 reward: 158
# Episode 4100 	 avg length: 254 	 reward: 140
# Episode 4120 	 avg length: 281 	 reward: 153
# Episode 4140 	 avg length: 279 	 reward: 167
# Episode 4160 	 avg length: 246 	 reward: 133
# Episode 4180 	 avg length: 231 	 reward: 124
# Episode 4200 	 avg length: 284 	 reward: 165
# Episode 4220 	 avg length: 268 	 reward: 161
# Episode 4240 	 avg length: 264 	 reward: 150
# Episode 4260 	 avg length: 280 	 reward: 151
# Episode 4280 	 avg length: 286 	 reward: 161
# Episode 4300 	 avg length: 233 	 reward: 144
# Episode 4320 	 avg length: 247 	 reward: 149
# Episode 4340 	 avg length: 228 	 reward: 120
# Episode 4360 	 avg length: 244 	 reward: 139
# Episode 4380 	 avg length: 270 	 reward: 145
# Episode 4400 	 avg length: 285 	 reward: 167
# Episode 4420 	 avg length: 269 	 reward: 155
# Episode 4440 	 avg length: 273 	 reward: 161
# Episode 4460 	 avg length: 286 	 reward: 165
# Episode 4480 	 avg length: 262 	 reward: 162
# Episode 4500 	 avg length: 278 	 reward: 160
# Episode 4520 	 avg length: 247 	 reward: 136
# Episode 4540 	 avg length: 282 	 reward: 173
# Episode 4560 	 avg length: 264 	 reward: 140
# Episode 4580 	 avg length: 247 	 reward: 150
# Episode 4600 	 avg length: 232 	 reward: 113
# Episode 4620 	 avg length: 262 	 reward: 135
# Episode 4640 	 avg length: 262 	 reward: 158
# Episode 4660 	 avg length: 276 	 reward: 136
# Episode 4680 	 avg length: 283 	 reward: 149
# Episode 4700 	 avg length: 276 	 reward: 141
# Episode 4720 	 avg length: 264 	 reward: 139
# Episode 4740 	 avg length: 280 	 reward: 151
# Episode 4760 	 avg length: 266 	 reward: 152
# Episode 4780 	 avg length: 258 	 reward: 149
# Episode 4800 	 avg length: 281 	 reward: 164
# Episode 4820 	 avg length: 282 	 reward: 155
# Episode 4840 	 avg length: 275 	 reward: 140
# Episode 4860 	 avg length: 258 	 reward: 141
# Episode 4880 	 avg length: 236 	 reward: 119
# Episode 4900 	 avg length: 251 	 reward: 125
# Episode 4920 	 avg length: 264 	 reward: 160
# Episode 4940 	 avg length: 244 	 reward: 129
# Episode 4960 	 avg length: 221 	 reward: 107
# Episode 4980 	 avg length: 264 	 reward: 162
# Episode 5000 	 avg length: 282 	 reward: 165
# Episode 5020 	 avg length: 244 	 reward: 130
# Episode 5040 	 avg length: 231 	 reward: 125
# Episode 5060 	 avg length: 255 	 reward: 145
# Episode 5080 	 avg length: 197 	 reward: 104
# Episode 5100 	 avg length: 204 	 reward: 108
# Episode 5120 	 avg length: 183 	 reward: 86
# Episode 5140 	 avg length: 232 	 reward: 129
# Episode 5160 	 avg length: 240 	 reward: 132
# Episode 5180 	 avg length: 253 	 reward: 130
# Episode 5200 	 avg length: 264 	 reward: 141
# Episode 5220 	 avg length: 289 	 reward: 164
# Episode 5240 	 avg length: 239 	 reward: 135
# Episode 5260 	 avg length: 260 	 reward: 139
# Episode 5280 	 avg length: 258 	 reward: 142
# Episode 5300 	 avg length: 287 	 reward: 158
# Episode 5320 	 avg length: 288 	 reward: 169
# Episode 5340 	 avg length: 260 	 reward: 133
# Episode 5360 	 avg length: 271 	 reward: 144
# Episode 5380 	 avg length: 244 	 reward: 128
# Episode 5400 	 avg length: 267 	 reward: 137
# Episode 5420 	 avg length: 246 	 reward: 129
# Episode 5440 	 avg length: 253 	 reward: 133
# Episode 5460 	 avg length: 242 	 reward: 122
# Episode 5480 	 avg length: 257 	 reward: 144
# Episode 5500 	 avg length: 245 	 reward: 125
# Episode 5520 	 avg length: 241 	 reward: 136
# Episode 5540 	 avg length: 239 	 reward: 144
# Episode 5560 	 avg length: 251 	 reward: 144
# Episode 5580 	 avg length: 276 	 reward: 158
# Episode 5600 	 avg length: 258 	 reward: 145
# Episode 5620 	 avg length: 233 	 reward: 142
# Episode 5640 	 avg length: 260 	 reward: 145
# Episode 5660 	 avg length: 238 	 reward: 135
# Episode 5680 	 avg length: 264 	 reward: 153
# Episode 5700 	 avg length: 262 	 reward: 145
# Episode 5720 	 avg length: 251 	 reward: 139
# Episode 5740 	 avg length: 241 	 reward: 128
# Episode 5760 	 avg length: 258 	 reward: 136
# Episode 5780 	 avg length: 243 	 reward: 141
# Episode 5800 	 avg length: 265 	 reward: 130
# Episode 5820 	 avg length: 266 	 reward: 164
# Episode 5840 	 avg length: 275 	 reward: 154
# Episode 5860 	 avg length: 254 	 reward: 148
# Episode 5880 	 avg length: 271 	 reward: 155
# Episode 5900 	 avg length: 255 	 reward: 149
# Episode 5920 	 avg length: 234 	 reward: 131
# Episode 5940 	 avg length: 256 	 reward: 147
# Episode 5960 	 avg length: 236 	 reward: 114
# Episode 5980 	 avg length: 251 	 reward: 133
# Episode 6000 	 avg length: 269 	 reward: 139
# Episode 6020 	 avg length: 232 	 reward: 105
# Episode 6040 	 avg length: 213 	 reward: 99
# Episode 6060 	 avg length: 211 	 reward: 94
# Episode 6080 	 avg length: 228 	 reward: 116
# Episode 6100 	 avg length: 254 	 reward: 141
# Episode 6120 	 avg length: 211 	 reward: 116
# Episode 6140 	 avg length: 272 	 reward: 156
# Episode 6160 	 avg length: 266 	 reward: 137
# Episode 6180 	 avg length: 271 	 reward: 137
# Episode 6200 	 avg length: 185 	 reward: 80
# Episode 6220 	 avg length: 235 	 reward: 128
# Episode 6240 	 avg length: 246 	 reward: 125
# Episode 6260 	 avg length: 214 	 reward: 117
# Episode 6280 	 avg length: 224 	 reward: 102
# Episode 6300 	 avg length: 261 	 reward: 113
# Episode 6320 	 avg length: 264 	 reward: 103
# Episode 6340 	 avg length: 275 	 reward: 103
# Episode 6360 	 avg length: 280 	 reward: 111
# Episode 6380 	 avg length: 265 	 reward: 105
# Episode 6400 	 avg length: 278 	 reward: 134
# Episode 6420 	 avg length: 252 	 reward: 140
# Episode 6440 	 avg length: 279 	 reward: 124
# Episode 6460 	 avg length: 281 	 reward: 148
# Episode 6480 	 avg length: 258 	 reward: 125
# Episode 6500 	 avg length: 263 	 reward: 145
# Episode 6520 	 avg length: 220 	 reward: 129
# Episode 6540 	 avg length: 241 	 reward: 146
# Episode 6560 	 avg length: 233 	 reward: 133
# Episode 6580 	 avg length: 240 	 reward: 127
# Episode 6600 	 avg length: 231 	 reward: 118
# Episode 6620 	 avg length: 249 	 reward: 147
# Episode 6640 	 avg length: 207 	 reward: 110
# Episode 6660 	 avg length: 221 	 reward: 130
# Episode 6680 	 avg length: 261 	 reward: 140
# Episode 6700 	 avg length: 259 	 reward: 134
# Episode 6720 	 avg length: 232 	 reward: 139
# Episode 6740 	 avg length: 215 	 reward: 129
# Episode 6760 	 avg length: 258 	 reward: 145
# Episode 6780 	 avg length: 249 	 reward: 161
# Episode 6800 	 avg length: 285 	 reward: 153
# Episode 6820 	 avg length: 203 	 reward: 121
# Episode 6840 	 avg length: 237 	 reward: 130
# Episode 6860 	 avg length: 255 	 reward: 107
# Episode 6880 	 avg length: 260 	 reward: 131
# Episode 6900 	 avg length: 289 	 reward: 159
# Episode 6920 	 avg length: 271 	 reward: 148
# Episode 6940 	 avg length: 250 	 reward: 147
# Episode 6960 	 avg length: 242 	 reward: 132
# Episode 6980 	 avg length: 237 	 reward: 94
# Episode 7000 	 avg length: 253 	 reward: 123
# Episode 7020 	 avg length: 245 	 reward: 130
# Episode 7040 	 avg length: 182 	 reward: 79
# Episode 7060 	 avg length: 255 	 reward: 129
# Episode 7080 	 avg length: 239 	 reward: 108
# Episode 7100 	 avg length: 222 	 reward: 91
# Episode 7120 	 avg length: 284 	 reward: 133
# Episode 7140 	 avg length: 284 	 reward: 121
# Episode 7160 	 avg length: 247 	 reward: 140
# Episode 7180 	 avg length: 245 	 reward: 121
# Episode 7200 	 avg length: 252 	 reward: 134
# Episode 7220 	 avg length: 251 	 reward: 101
# Episode 7240 	 avg length: 244 	 reward: 100
# Episode 7260 	 avg length: 250 	 reward: 117
# Episode 7280 	 avg length: 242 	 reward: 112
# Episode 7300 	 avg length: 273 	 reward: 130
# Episode 7320 	 avg length: 266 	 reward: 129
# Episode 7340 	 avg length: 243 	 reward: 88
# Episode 7360 	 avg length: 270 	 reward: 117
# Episode 7380 	 avg length: 215 	 reward: 104
# Episode 7400 	 avg length: 282 	 reward: 127
# Episode 7420 	 avg length: 250 	 reward: 106
# Episode 7440 	 avg length: 274 	 reward: 122
# Episode 7460 	 avg length: 260 	 reward: 154
# Episode 7480 	 avg length: 234 	 reward: 94
# Episode 7500 	 avg length: 262 	 reward: 130
# Episode 7520 	 avg length: 244 	 reward: 94
# Episode 7540 	 avg length: 226 	 reward: 95
# Episode 7560 	 avg length: 249 	 reward: 105
# Episode 7580 	 avg length: 269 	 reward: 116
# Episode 7600 	 avg length: 278 	 reward: 118
# Episode 7620 	 avg length: 268 	 reward: 124
# Episode 7640 	 avg length: 244 	 reward: 107
# Episode 7660 	 avg length: 266 	 reward: 134
# Episode 7680 	 avg length: 294 	 reward: 145
# Episode 7700 	 avg length: 252 	 reward: 126
# Episode 7720 	 avg length: 283 	 reward: 140
# Episode 7740 	 avg length: 280 	 reward: 136
# Episode 7760 	 avg length: 273 	 reward: 126
# Episode 7780 	 avg length: 286 	 reward: 160
# Episode 7800 	 avg length: 259 	 reward: 144
# Episode 7820 	 avg length: 265 	 reward: 137
# Episode 7840 	 avg length: 267 	 reward: 163
# Episode 7860 	 avg length: 235 	 reward: 124
# Episode 7880 	 avg length: 254 	 reward: 161
# Episode 7900 	 avg length: 263 	 reward: 147
# Episode 7920 	 avg length: 251 	 reward: 134
# Episode 7940 	 avg length: 258 	 reward: 137
# Episode 7960 	 avg length: 238 	 reward: 140
# Episode 7980 	 avg length: 239 	 reward: 163
# Episode 8000 	 avg length: 215 	 reward: 91
# Episode 8020 	 avg length: 211 	 reward: 98
# Episode 8040 	 avg length: 258 	 reward: 160
# Episode 8060 	 avg length: 240 	 reward: 156
# Episode 8080 	 avg length: 231 	 reward: 167
# Episode 8100 	 avg length: 247 	 reward: 145
# Episode 8120 	 avg length: 234 	 reward: 146
# Episode 8140 	 avg length: 239 	 reward: 110
# Episode 8160 	 avg length: 261 	 reward: 100
# Episode 8180 	 avg length: 268 	 reward: 166
# Episode 8200 	 avg length: 258 	 reward: 107
# Episode 8220 	 avg length: 268 	 reward: 157
# Episode 8240 	 avg length: 257 	 reward: 131
# Episode 8260 	 avg length: 233 	 reward: 93
# Episode 8280 	 avg length: 256 	 reward: 134
# Episode 8300 	 avg length: 256 	 reward: 127
# Episode 8320 	 avg length: 261 	 reward: 155
# Episode 8340 	 avg length: 255 	 reward: 142
# Episode 8360 	 avg length: 227 	 reward: 103
# Episode 8380 	 avg length: 236 	 reward: 152
# Episode 8400 	 avg length: 242 	 reward: 132
# Episode 8420 	 avg length: 270 	 reward: 136
# Episode 8440 	 avg length: 266 	 reward: 159
# Episode 8460 	 avg length: 263 	 reward: 137
# Episode 8480 	 avg length: 245 	 reward: 149
# Episode 8500 	 avg length: 245 	 reward: 142
# Episode 8520 	 avg length: 225 	 reward: 150
# Episode 8540 	 avg length: 234 	 reward: 131
# Episode 8560 	 avg length: 216 	 reward: 108
# Episode 8580 	 avg length: 237 	 reward: 141
# Episode 8600 	 avg length: 247 	 reward: 149
# Episode 8620 	 avg length: 232 	 reward: 117
# Episode 8640 	 avg length: 223 	 reward: 133
# Episode 8660 	 avg length: 214 	 reward: 116
# Episode 8680 	 avg length: 242 	 reward: 145
# Episode 8700 	 avg length: 200 	 reward: 111
# Episode 8720 	 avg length: 229 	 reward: 122
# Episode 8740 	 avg length: 226 	 reward: 118
# Episode 8760 	 avg length: 247 	 reward: 128
# Episode 8780 	 avg length: 222 	 reward: 134
# Episode 8800 	 avg length: 258 	 reward: 148
# Episode 8820 	 avg length: 200 	 reward: 120
# Episode 8840 	 avg length: 209 	 reward: 104
# Episode 8860 	 avg length: 204 	 reward: 117
# Episode 8880 	 avg length: 213 	 reward: 118
# Episode 8900 	 avg length: 220 	 reward: 111
# Episode 8920 	 avg length: 253 	 reward: 142
# Episode 8940 	 avg length: 230 	 reward: 124
# Episode 8960 	 avg length: 246 	 reward: 124
# Episode 8980 	 avg length: 241 	 reward: 113
# Episode 9000 	 avg length: 241 	 reward: 127
# Episode 9020 	 avg length: 225 	 reward: 131
# Episode 9040 	 avg length: 204 	 reward: 122
# Episode 9060 	 avg length: 211 	 reward: 98
# Episode 9080 	 avg length: 211 	 reward: 104
# Episode 9100 	 avg length: 224 	 reward: 108
# Episode 9120 	 avg length: 213 	 reward: 140
# Episode 9140 	 avg length: 209 	 reward: 107
# Episode 9160 	 avg length: 224 	 reward: 116
# Episode 9180 	 avg length: 213 	 reward: 110
# Episode 9200 	 avg length: 243 	 reward: 122
# Episode 9220 	 avg length: 227 	 reward: 142
# Episode 9240 	 avg length: 212 	 reward: 94
# Episode 9260 	 avg length: 235 	 reward: 125
# Episode 9280 	 avg length: 254 	 reward: 118
# Episode 9300 	 avg length: 194 	 reward: 94
# Episode 9320 	 avg length: 236 	 reward: 127
# Episode 9340 	 avg length: 237 	 reward: 113
# Episode 9360 	 avg length: 198 	 reward: 84
# Episode 9380 	 avg length: 182 	 reward: 74
# Episode 9400 	 avg length: 162 	 reward: 93
# Episode 9420 	 avg length: 180 	 reward: 74
# Episode 9440 	 avg length: 180 	 reward: 94
# Episode 9460 	 avg length: 196 	 reward: 107
# Episode 9480 	 avg length: 202 	 reward: 112
# Episode 9500 	 avg length: 177 	 reward: 102
# Episode 9520 	 avg length: 168 	 reward: 71
# Episode 9540 	 avg length: 189 	 reward: 100
# Episode 9560 	 avg length: 174 	 reward: 83
# Episode 9580 	 avg length: 199 	 reward: 77
# Episode 9600 	 avg length: 219 	 reward: 111
# Episode 9620 	 avg length: 148 	 reward: 76
# Episode 9640 	 avg length: 186 	 reward: 118
# Episode 9660 	 avg length: 200 	 reward: 91
# Episode 9680 	 avg length: 212 	 reward: 103
# Episode 9700 	 avg length: 238 	 reward: 124
# Episode 9720 	 avg length: 196 	 reward: 58
# Episode 9740 	 avg length: 228 	 reward: 120
# Episode 9760 	 avg length: 236 	 reward: 117
# Episode 9780 	 avg length: 223 	 reward: 130
# Episode 9800 	 avg length: 235 	 reward: 133
# Episode 9820 	 avg length: 220 	 reward: 97
# Episode 9840 	 avg length: 240 	 reward: 102
# Episode 9860 	 avg length: 238 	 reward: 80
# Episode 9880 	 avg length: 249 	 reward: 87
# Episode 9900 	 avg length: 260 	 reward: 138
# Episode 9920 	 avg length: 207 	 reward: 73
# Episode 9940 	 avg length: 255 	 reward: 115
# Episode 9960 	 avg length: 243 	 reward: 92
# Episode 9980 	 avg length: 249 	 reward: 152
# Episode 10000 	 avg length: 200 	 reward: 49
# Episode 10020 	 avg length: 218 	 reward: 86
# Episode 10040 	 avg length: 210 	 reward: 77
# Episode 10060 	 avg length: 204 	 reward: 59
# Episode 10080 	 avg length: 257 	 reward: 97
# Episode 10100 	 avg length: 223 	 reward: 97
# Episode 10120 	 avg length: 178 	 reward: 48
# Episode 10140 	 avg length: 245 	 reward: 106
# Episode 10160 	 avg length: 223 	 reward: 107
# Episode 10180 	 avg length: 198 	 reward: 83
# Episode 10200 	 avg length: 236 	 reward: 124
# Episode 10220 	 avg length: 223 	 reward: 117
# Episode 10240 	 avg length: 177 	 reward: 79
# Episode 10260 	 avg length: 238 	 reward: 96
# Episode 10280 	 avg length: 224 	 reward: 130
# Episode 10300 	 avg length: 206 	 reward: 75
# Episode 10320 	 avg length: 220 	 reward: 108
# Episode 10340 	 avg length: 206 	 reward: 115
# Episode 10360 	 avg length: 182 	 reward: 97
# Episode 10380 	 avg length: 209 	 reward: 134
# Episode 10400 	 avg length: 206 	 reward: 119
# Episode 10420 	 avg length: 215 	 reward: 137
# Episode 10440 	 avg length: 226 	 reward: 121
# Episode 10460 	 avg length: 209 	 reward: 104
# Episode 10480 	 avg length: 235 	 reward: 141
# Episode 10500 	 avg length: 226 	 reward: 153
# Episode 10520 	 avg length: 189 	 reward: 71
# Episode 10540 	 avg length: 217 	 reward: 112
# Episode 10560 	 avg length: 221 	 reward: 122
# Episode 10580 	 avg length: 209 	 reward: 118
# Episode 10600 	 avg length: 180 	 reward: 138
# Episode 10620 	 avg length: 203 	 reward: 102
# Episode 10640 	 avg length: 228 	 reward: 125
# Episode 10660 	 avg length: 186 	 reward: 92
# Episode 10680 	 avg length: 193 	 reward: 121
# Episode 10700 	 avg length: 194 	 reward: 96
# Episode 10720 	 avg length: 255 	 reward: 132
# Episode 10740 	 avg length: 191 	 reward: 87
# Episode 10760 	 avg length: 199 	 reward: 116
# Episode 10780 	 avg length: 235 	 reward: 111
# Episode 10800 	 avg length: 223 	 reward: 118
# Episode 10820 	 avg length: 253 	 reward: 122
# Episode 10840 	 avg length: 232 	 reward: 147
# Episode 10860 	 avg length: 232 	 reward: 145
# Episode 10880 	 avg length: 214 	 reward: 110
# Episode 10900 	 avg length: 218 	 reward: 108
# Episode 10920 	 avg length: 216 	 reward: 120
# Episode 10940 	 avg length: 213 	 reward: 122
# Episode 10960 	 avg length: 260 	 reward: 153
# Episode 10980 	 avg length: 201 	 reward: 127
# Episode 11000 	 avg length: 201 	 reward: 123
# Episode 11020 	 avg length: 253 	 reward: 122
# Episode 11040 	 avg length: 240 	 reward: 111
# Episode 11060 	 avg length: 219 	 reward: 111
# Episode 11080 	 avg length: 236 	 reward: 126
# Episode 11100 	 avg length: 241 	 reward: 130
# Episode 11120 	 avg length: 230 	 reward: 136
# Episode 11140 	 avg length: 203 	 reward: 92
# Episode 11160 	 avg length: 228 	 reward: 149
# Episode 11180 	 avg length: 200 	 reward: 103
# Episode 11200 	 avg length: 199 	 reward: 105
# Episode 11220 	 avg length: 232 	 reward: 132
# Episode 11240 	 avg length: 224 	 reward: 126
# Episode 11260 	 avg length: 267 	 reward: 138
# Episode 11280 	 avg length: 207 	 reward: 96
# Episode 11300 	 avg length: 187 	 reward: 92
# Episode 11320 	 avg length: 235 	 reward: 142
# Episode 11340 	 avg length: 231 	 reward: 109
# Episode 11360 	 avg length: 263 	 reward: 127
# Episode 11380 	 avg length: 222 	 reward: 125
# Episode 11400 	 avg length: 219 	 reward: 123
# Episode 11420 	 avg length: 224 	 reward: 112
# Episode 11440 	 avg length: 249 	 reward: 122
# Episode 11460 	 avg length: 243 	 reward: 103
# Episode 11480 	 avg length: 227 	 reward: 116
# Episode 11500 	 avg length: 250 	 reward: 130
# Episode 11520 	 avg length: 259 	 reward: 132
# Episode 11540 	 avg length: 259 	 reward: 135
# Episode 11560 	 avg length: 191 	 reward: 103
# Episode 11580 	 avg length: 200 	 reward: 89
# Episode 11600 	 avg length: 189 	 reward: 69
# Episode 11620 	 avg length: 227 	 reward: 111
# Episode 11640 	 avg length: 199 	 reward: 115
# Episode 11660 	 avg length: 197 	 reward: 110
# Episode 11680 	 avg length: 221 	 reward: 91
# Episode 11700 	 avg length: 218 	 reward: 118
# Episode 11720 	 avg length: 197 	 reward: 92
# Episode 11740 	 avg length: 211 	 reward: 59
# Episode 11760 	 avg length: 218 	 reward: 79
# Episode 11780 	 avg length: 202 	 reward: 81
# Episode 11800 	 avg length: 220 	 reward: 130
# Episode 11820 	 avg length: 192 	 reward: 53
# Episode 11840 	 avg length: 242 	 reward: 110
# Episode 11860 	 avg length: 208 	 reward: 90
# Episode 11880 	 avg length: 194 	 reward: 84
# Episode 11900 	 avg length: 221 	 reward: 98
# Episode 11920 	 avg length: 253 	 reward: 148
# Episode 11940 	 avg length: 226 	 reward: 107
# Episode 11960 	 avg length: 214 	 reward: 120
# Episode 11980 	 avg length: 251 	 reward: 95
# Episode 12000 	 avg length: 277 	 reward: 96
# Episode 12020 	 avg length: 256 	 reward: 104
# Episode 12040 	 avg length: 205 	 reward: 90
# Episode 12060 	 avg length: 234 	 reward: 79
# Episode 12080 	 avg length: 214 	 reward: 98
# Episode 12100 	 avg length: 206 	 reward: 85
# Episode 12120 	 avg length: 210 	 reward: 146
# Episode 12140 	 avg length: 195 	 reward: 107
# Episode 12160 	 avg length: 202 	 reward: 73
# Episode 12180 	 avg length: 211 	 reward: 107
# Episode 12200 	 avg length: 196 	 reward: 61
# Episode 12220 	 avg length: 247 	 reward: 123
# Episode 12240 	 avg length: 176 	 reward: 67
# Episode 12260 	 avg length: 232 	 reward: 127
# Episode 12280 	 avg length: 238 	 reward: 80
# Episode 12300 	 avg length: 258 	 reward: 73
# Episode 12320 	 avg length: 237 	 reward: 42
# Episode 12340 	 avg length: 208 	 reward: 86
# Episode 12360 	 avg length: 219 	 reward: 90
# Episode 12380 	 avg length: 248 	 reward: 141
# Episode 12400 	 avg length: 171 	 reward: 21
# Episode 12420 	 avg length: 233 	 reward: 108
# Episode 12440 	 avg length: 212 	 reward: 87
# Episode 12460 	 avg length: 209 	 reward: 82
# Episode 12480 	 avg length: 215 	 reward: 98
# Episode 12500 	 avg length: 232 	 reward: 81
# Episode 12520 	 avg length: 226 	 reward: 106
# Episode 12540 	 avg length: 215 	 reward: 111
# Episode 12560 	 avg length: 212 	 reward: 75
# Episode 12580 	 avg length: 230 	 reward: 134
# Episode 12600 	 avg length: 237 	 reward: 107
# Episode 12620 	 avg length: 240 	 reward: 159
# Episode 12640 	 avg length: 253 	 reward: 114
# Episode 12660 	 avg length: 224 	 reward: 121
# Episode 12680 	 avg length: 238 	 reward: 156
# Episode 12700 	 avg length: 266 	 reward: 163
# Episode 12720 	 avg length: 225 	 reward: 101
# Episode 12740 	 avg length: 228 	 reward: 89
# Episode 12760 	 avg length: 234 	 reward: 127
# Episode 12780 	 avg length: 224 	 reward: 121
# Episode 12800 	 avg length: 217 	 reward: 82
# Episode 12820 	 avg length: 230 	 reward: 100
# Episode 12840 	 avg length: 245 	 reward: 126
# Episode 12860 	 avg length: 239 	 reward: 86
# Episode 12880 	 avg length: 217 	 reward: 85
# Episode 12900 	 avg length: 272 	 reward: 161
# Episode 12920 	 avg length: 223 	 reward: 89
# Episode 12940 	 avg length: 248 	 reward: 120
# Episode 12960 	 avg length: 209 	 reward: 111
# Episode 12980 	 avg length: 231 	 reward: 100
# Episode 13000 	 avg length: 249 	 reward: 118
# Episode 13020 	 avg length: 240 	 reward: 125
# Episode 13040 	 avg length: 240 	 reward: 92
# Episode 13060 	 avg length: 246 	 reward: 119
# Episode 13080 	 avg length: 237 	 reward: 126
# Episode 13100 	 avg length: 211 	 reward: 113
# Episode 13120 	 avg length: 212 	 reward: 113
# Episode 13140 	 avg length: 232 	 reward: 94
# Episode 13160 	 avg length: 239 	 reward: 112
# Episode 13180 	 avg length: 238 	 reward: 104
# Episode 13200 	 avg length: 254 	 reward: 113
# Episode 13220 	 avg length: 236 	 reward: 93
# Episode 13240 	 avg length: 241 	 reward: 97
# Episode 13260 	 avg length: 242 	 reward: 116
# Episode 13280 	 avg length: 195 	 reward: 98
# Episode 13300 	 avg length: 188 	 reward: 88
# Episode 13320 	 avg length: 248 	 reward: 160
# Episode 13340 	 avg length: 248 	 reward: 124
# Episode 13360 	 avg length: 204 	 reward: 93
# Episode 13380 	 avg length: 211 	 reward: 112
# Episode 13400 	 avg length: 218 	 reward: 110
# Episode 13420 	 avg length: 221 	 reward: 102
# Episode 13440 	 avg length: 252 	 reward: 109
# Episode 13460 	 avg length: 238 	 reward: 142
# Episode 13480 	 avg length: 220 	 reward: 110
# Episode 13500 	 avg length: 234 	 reward: 120
# Episode 13520 	 avg length: 274 	 reward: 145
# Episode 13540 	 avg length: 251 	 reward: 133
# Episode 13560 	 avg length: 239 	 reward: 93
# Episode 13580 	 avg length: 187 	 reward: 114
# Episode 13600 	 avg length: 218 	 reward: 96
# Episode 13620 	 avg length: 218 	 reward: 104
# Episode 13640 	 avg length: 266 	 reward: 161
# Episode 13660 	 avg length: 217 	 reward: 122
# Episode 13680 	 avg length: 207 	 reward: 113
# Episode 13700 	 avg length: 219 	 reward: 130
# Episode 13720 	 avg length: 251 	 reward: 134
# Episode 13740 	 avg length: 246 	 reward: 135
# Episode 13760 	 avg length: 238 	 reward: 102
# Episode 13780 	 avg length: 253 	 reward: 125
# Episode 13800 	 avg length: 234 	 reward: 114
# Episode 13820 	 avg length: 237 	 reward: 134
# Episode 13840 	 avg length: 237 	 reward: 125
# Episode 13860 	 avg length: 250 	 reward: 137
# Episode 13880 	 avg length: 217 	 reward: 76
# Episode 13900 	 avg length: 216 	 reward: 106
# Episode 13920 	 avg length: 252 	 reward: 95
# Episode 13940 	 avg length: 259 	 reward: 84
# Episode 13960 	 avg length: 231 	 reward: 92
# Episode 13980 	 avg length: 207 	 reward: 42
# Episode 14000 	 avg length: 223 	 reward: 96
# Episode 14020 	 avg length: 190 	 reward: 51
# Episode 14040 	 avg length: 234 	 reward: 102
# Episode 14060 	 avg length: 227 	 reward: 97
# Episode 14080 	 avg length: 210 	 reward: 96
# Episode 14100 	 avg length: 213 	 reward: 76
# Episode 14120 	 avg length: 215 	 reward: 93
# Episode 14140 	 avg length: 205 	 reward: 101
# Episode 14160 	 avg length: 220 	 reward: 98
# Episode 14180 	 avg length: 192 	 reward: 81
# Episode 14200 	 avg length: 217 	 reward: 86
# Episode 14220 	 avg length: 209 	 reward: 91
# Episode 14240 	 avg length: 227 	 reward: 122
# Episode 14260 	 avg length: 272 	 reward: 146
# Episode 14280 	 avg length: 215 	 reward: 95
# Episode 14300 	 avg length: 225 	 reward: 127
# Episode 14320 	 avg length: 250 	 reward: 134
# Episode 14340 	 avg length: 230 	 reward: 109
# Episode 14360 	 avg length: 198 	 reward: 76
# Episode 14380 	 avg length: 228 	 reward: 154
# Episode 14400 	 avg length: 221 	 reward: 88
# Episode 14420 	 avg length: 215 	 reward: 109
# Episode 14440 	 avg length: 264 	 reward: 152
# Episode 14460 	 avg length: 228 	 reward: 135
# Episode 14480 	 avg length: 246 	 reward: 159
# Episode 14500 	 avg length: 227 	 reward: 113
# Episode 14520 	 avg length: 230 	 reward: 104
# Episode 14540 	 avg length: 227 	 reward: 128
# Episode 14560 	 avg length: 256 	 reward: 126
# Episode 14580 	 avg length: 243 	 reward: 132
# Episode 14600 	 avg length: 237 	 reward: 128
# Episode 14620 	 avg length: 234 	 reward: 125
# Episode 14640 	 avg length: 244 	 reward: 114
# Episode 14660 	 avg length: 218 	 reward: 122
# Episode 14680 	 avg length: 253 	 reward: 127
# Episode 14700 	 avg length: 249 	 reward: 172
# Episode 14720 	 avg length: 221 	 reward: 154
# Episode 14740 	 avg length: 249 	 reward: 166
# Episode 14760 	 avg length: 217 	 reward: 132
# Episode 14780 	 avg length: 195 	 reward: 95
# Episode 14800 	 avg length: 163 	 reward: 87
# Episode 14820 	 avg length: 188 	 reward: 128
# Episode 14840 	 avg length: 205 	 reward: 84
# Episode 14860 	 avg length: 184 	 reward: 88
# Episode 14880 	 avg length: 224 	 reward: 123
# Episode 14900 	 avg length: 205 	 reward: 138
# Episode 14920 	 avg length: 226 	 reward: 140
# Episode 14940 	 avg length: 221 	 reward: 101
# Episode 14960 	 avg length: 194 	 reward: 120
# Episode 14980 	 avg length: 223 	 reward: 127
# Episode 15000 	 avg length: 176 	 reward: 62
# Episode 15020 	 avg length: 216 	 reward: 121
# Episode 15040 	 avg length: 212 	 reward: 103
# Episode 15060 	 avg length: 195 	 reward: 106
# Episode 15080 	 avg length: 228 	 reward: 135
# Episode 15100 	 avg length: 236 	 reward: 108
# Episode 15120 	 avg length: 229 	 reward: 110
# Episode 15140 	 avg length: 211 	 reward: 90
# Episode 15160 	 avg length: 196 	 reward: 102
# Episode 15180 	 avg length: 230 	 reward: 123
# Episode 15200 	 avg length: 219 	 reward: 108
# Episode 15220 	 avg length: 242 	 reward: 117
# Episode 15240 	 avg length: 261 	 reward: 129
# Episode 15260 	 avg length: 226 	 reward: 109
# Episode 15280 	 avg length: 272 	 reward: 150
# Episode 15300 	 avg length: 239 	 reward: 130
# Episode 15320 	 avg length: 217 	 reward: 121
# Episode 15340 	 avg length: 214 	 reward: 78
# Episode 15360 	 avg length: 240 	 reward: 123
# Episode 15380 	 avg length: 208 	 reward: 119
# Episode 15400 	 avg length: 224 	 reward: 99
# Episode 15420 	 avg length: 219 	 reward: 139
# Episode 15440 	 avg length: 203 	 reward: 124
# Episode 15460 	 avg length: 190 	 reward: 120
# Episode 15480 	 avg length: 260 	 reward: 148
# Episode 15500 	 avg length: 227 	 reward: 129
# Episode 15520 	 avg length: 209 	 reward: 141
# Episode 15540 	 avg length: 173 	 reward: 90
# Episode 15560 	 avg length: 170 	 reward: 67
# Episode 15580 	 avg length: 224 	 reward: 114
# Episode 15600 	 avg length: 275 	 reward: 146
# Episode 15620 	 avg length: 203 	 reward: 108
# Episode 15640 	 avg length: 210 	 reward: 100
# Episode 15660 	 avg length: 213 	 reward: 113
# Episode 15680 	 avg length: 225 	 reward: 104
# Episode 15700 	 avg length: 221 	 reward: 125
# Episode 15720 	 avg length: 216 	 reward: 128
# Episode 15740 	 avg length: 162 	 reward: 57
# Episode 15760 	 avg length: 236 	 reward: 130
# Episode 15780 	 avg length: 225 	 reward: 115
# Episode 15800 	 avg length: 169 	 reward: 123
# Episode 15820 	 avg length: 207 	 reward: 113
# Episode 15840 	 avg length: 208 	 reward: 76
# Episode 15860 	 avg length: 209 	 reward: 85
# Episode 15880 	 avg length: 210 	 reward: 119
# Episode 15900 	 avg length: 242 	 reward: 134
# Episode 15920 	 avg length: 212 	 reward: 91
# Episode 15940 	 avg length: 210 	 reward: 94
# Episode 15960 	 avg length: 225 	 reward: 143
# Episode 15980 	 avg length: 208 	 reward: 73
# Episode 16000 	 avg length: 232 	 reward: 114
# Episode 16020 	 avg length: 259 	 reward: 143
# Episode 16040 	 avg length: 244 	 reward: 128
# Episode 16060 	 avg length: 213 	 reward: 123
# Episode 16080 	 avg length: 234 	 reward: 129
# Episode 16100 	 avg length: 232 	 reward: 118
# Episode 16120 	 avg length: 228 	 reward: 107
# Episode 16140 	 avg length: 236 	 reward: 133
# Episode 16160 	 avg length: 222 	 reward: 92
# Episode 16180 	 avg length: 244 	 reward: 117
# Episode 16200 	 avg length: 244 	 reward: 126
# Episode 16220 	 avg length: 253 	 reward: 109
# Episode 16240 	 avg length: 238 	 reward: 119
# Episode 16260 	 avg length: 214 	 reward: 71
# Episode 16280 	 avg length: 225 	 reward: 81
# Episode 16300 	 avg length: 260 	 reward: 134
# Episode 16320 	 avg length: 243 	 reward: 95
# Episode 16340 	 avg length: 216 	 reward: 90
# Episode 16360 	 avg length: 238 	 reward: 112
# Episode 16380 	 avg length: 222 	 reward: 66
# Episode 16400 	 avg length: 268 	 reward: 140
# Episode 16420 	 avg length: 229 	 reward: 90
# Episode 16440 	 avg length: 272 	 reward: 132
# Episode 16460 	 avg length: 220 	 reward: 94
# Episode 16480 	 avg length: 257 	 reward: 131
# Episode 16500 	 avg length: 258 	 reward: 141
# Episode 16520 	 avg length: 256 	 reward: 119
# Episode 16540 	 avg length: 245 	 reward: 112
# Episode 16560 	 avg length: 257 	 reward: 133
# Episode 16580 	 avg length: 241 	 reward: 137
# Episode 16600 	 avg length: 246 	 reward: 104
# Episode 16620 	 avg length: 259 	 reward: 143
# Episode 16640 	 avg length: 264 	 reward: 109
# Episode 16660 	 avg length: 253 	 reward: 105
# Episode 16680 	 avg length: 259 	 reward: 138
# Episode 16700 	 avg length: 243 	 reward: 78
# Episode 16720 	 avg length: 272 	 reward: 132
# Episode 16740 	 avg length: 253 	 reward: 153
# Episode 16760 	 avg length: 269 	 reward: 161
# Episode 16780 	 avg length: 234 	 reward: 133
# Episode 16800 	 avg length: 264 	 reward: 117
# Episode 16820 	 avg length: 239 	 reward: 149
# Episode 16840 	 avg length: 220 	 reward: 125
# Episode 16860 	 avg length: 251 	 reward: 120
# Episode 16880 	 avg length: 238 	 reward: 168
# Episode 16900 	 avg length: 256 	 reward: 159
# Episode 16920 	 avg length: 235 	 reward: 149
# Episode 16940 	 avg length: 247 	 reward: 174
# Episode 16960 	 avg length: 256 	 reward: 133
# Episode 16980 	 avg length: 261 	 reward: 156
# Episode 17000 	 avg length: 249 	 reward: 128
# Episode 17020 	 avg length: 246 	 reward: 176
# Episode 17040 	 avg length: 251 	 reward: 153
# Episode 17060 	 avg length: 236 	 reward: 169
# Episode 17080 	 avg length: 235 	 reward: 169
# Episode 17100 	 avg length: 213 	 reward: 170
# Episode 17120 	 avg length: 264 	 reward: 161
# Episode 17140 	 avg length: 266 	 reward: 145
# Episode 17160 	 avg length: 239 	 reward: 112
# Episode 17180 	 avg length: 243 	 reward: 149
# Episode 17200 	 avg length: 208 	 reward: 95
# Episode 17220 	 avg length: 240 	 reward: 131
# Episode 17240 	 avg length: 227 	 reward: 109
# Episode 17260 	 avg length: 227 	 reward: 98
# Episode 17280 	 avg length: 241 	 reward: 124
# Episode 17300 	 avg length: 247 	 reward: 111
# Episode 17320 	 avg length: 235 	 reward: 131
# Episode 17340 	 avg length: 257 	 reward: 126
# Episode 17360 	 avg length: 235 	 reward: 120
# Episode 17380 	 avg length: 204 	 reward: 130
# Episode 17400 	 avg length: 259 	 reward: 119
# Episode 17420 	 avg length: 254 	 reward: 144
# Episode 17440 	 avg length: 244 	 reward: 115
# Episode 17460 	 avg length: 257 	 reward: 133
# Episode 17480 	 avg length: 275 	 reward: 130
# Episode 17500 	 avg length: 245 	 reward: 134
# Episode 17520 	 avg length: 257 	 reward: 139
# Episode 17540 	 avg length: 226 	 reward: 106
# Episode 17560 	 avg length: 263 	 reward: 109
# Episode 17580 	 avg length: 247 	 reward: 94
# Episode 17600 	 avg length: 234 	 reward: 86
# Episode 17620 	 avg length: 263 	 reward: 130
# Episode 17640 	 avg length: 268 	 reward: 100
# Episode 17660 	 avg length: 282 	 reward: 117
# Episode 17680 	 avg length: 254 	 reward: 126
# Episode 17700 	 avg length: 269 	 reward: 113
# Episode 17720 	 avg length: 273 	 reward: 105
# Episode 17740 	 avg length: 259 	 reward: 100
# Episode 17760 	 avg length: 234 	 reward: 128
# Episode 17780 	 avg length: 261 	 reward: 146
# Episode 17800 	 avg length: 239 	 reward: 103
# Episode 17820 	 avg length: 284 	 reward: 139
# Episode 17840 	 avg length: 260 	 reward: 122
# Episode 17860 	 avg length: 253 	 reward: 124
# Episode 17880 	 avg length: 259 	 reward: 135
# Episode 17900 	 avg length: 249 	 reward: 98
# Episode 17920 	 avg length: 259 	 reward: 109
# Episode 17940 	 avg length: 249 	 reward: 128
# Episode 17960 	 avg length: 209 	 reward: 114
# Episode 17980 	 avg length: 221 	 reward: 101
# Episode 18000 	 avg length: 221 	 reward: 116
# Episode 18020 	 avg length: 252 	 reward: 119
# Episode 18040 	 avg length: 237 	 reward: 114
# Episode 18060 	 avg length: 241 	 reward: 128
# Episode 18080 	 avg length: 236 	 reward: 102
# Episode 18100 	 avg length: 231 	 reward: 132
# Episode 18120 	 avg length: 224 	 reward: 136
# Episode 18140 	 avg length: 242 	 reward: 118
# Episode 18160 	 avg length: 244 	 reward: 138
# Episode 18180 	 avg length: 254 	 reward: 128
# Episode 18200 	 avg length: 251 	 reward: 135
# Episode 18220 	 avg length: 218 	 reward: 136
# Episode 18240 	 avg length: 232 	 reward: 160
# Episode 18260 	 avg length: 239 	 reward: 135
# Episode 18280 	 avg length: 259 	 reward: 150
# Episode 18300 	 avg length: 280 	 reward: 141
# Episode 18320 	 avg length: 238 	 reward: 154
# Episode 18340 	 avg length: 246 	 reward: 138
# Episode 18360 	 avg length: 230 	 reward: 107
# Episode 18380 	 avg length: 237 	 reward: 133
# Episode 18400 	 avg length: 227 	 reward: 136
# Episode 18420 	 avg length: 229 	 reward: 104
# Episode 18440 	 avg length: 215 	 reward: 130
# Episode 18460 	 avg length: 247 	 reward: 107
# Episode 18480 	 avg length: 237 	 reward: 99
# Episode 18500 	 avg length: 189 	 reward: 109
# Episode 18520 	 avg length: 202 	 reward: 107
# Episode 18540 	 avg length: 257 	 reward: 109
# Episode 18560 	 avg length: 201 	 reward: 94
# Episode 18580 	 avg length: 207 	 reward: 69
# Episode 18600 	 avg length: 195 	 reward: 83
# Episode 18620 	 avg length: 250 	 reward: 98
# Episode 18640 	 avg length: 220 	 reward: 81
# Episode 18660 	 avg length: 237 	 reward: 122
# Episode 18680 	 avg length: 268 	 reward: 147
# Episode 18700 	 avg length: 237 	 reward: 78
# Episode 18720 	 avg length: 250 	 reward: 104
# Episode 18740 	 avg length: 277 	 reward: 140
# Episode 18760 	 avg length: 229 	 reward: 52
# Episode 18780 	 avg length: 256 	 reward: 122
# Episode 18800 	 avg length: 231 	 reward: 94
# Episode 18820 	 avg length: 265 	 reward: 96
# Episode 18840 	 avg length: 248 	 reward: 96
# Episode 18860 	 avg length: 225 	 reward: 119
# Episode 18880 	 avg length: 258 	 reward: 140
# Episode 18900 	 avg length: 243 	 reward: 109
# Episode 18920 	 avg length: 247 	 reward: 97
# Episode 18940 	 avg length: 287 	 reward: 119
# Episode 18960 	 avg length: 247 	 reward: 111
# Episode 18980 	 avg length: 257 	 reward: 115
# Episode 19000 	 avg length: 236 	 reward: 106
# Episode 19020 	 avg length: 265 	 reward: 143
# Episode 19040 	 avg length: 207 	 reward: 114
# Episode 19060 	 avg length: 240 	 reward: 140
# Episode 19080 	 avg length: 187 	 reward: 97
# Episode 19100 	 avg length: 189 	 reward: 92
# Episode 19120 	 avg length: 225 	 reward: 133
# Episode 19140 	 avg length: 198 	 reward: 101
# Episode 19160 	 avg length: 176 	 reward: 90
# Episode 19180 	 avg length: 247 	 reward: 135
# Episode 19200 	 avg length: 211 	 reward: 132
# Episode 19220 	 avg length: 226 	 reward: 146
# Episode 19240 	 avg length: 238 	 reward: 136
# Episode 19260 	 avg length: 232 	 reward: 148
# Episode 19280 	 avg length: 230 	 reward: 169
# Episode 19300 	 avg length: 216 	 reward: 175
# Episode 19320 	 avg length: 170 	 reward: 116
# Episode 19340 	 avg length: 181 	 reward: 123
# Episode 19360 	 avg length: 215 	 reward: 183
# Episode 19380 	 avg length: 216 	 reward: 134
# Episode 19400 	 avg length: 201 	 reward: 131
# Episode 19420 	 avg length: 189 	 reward: 165
# Episode 19440 	 avg length: 217 	 reward: 202
# Episode 19460 	 avg length: 223 	 reward: 183
# Episode 19480 	 avg length: 203 	 reward: 157
# Episode 19500 	 avg length: 193 	 reward: 180
# Episode 19520 	 avg length: 172 	 reward: 145
# Episode 19540 	 avg length: 196 	 reward: 135
# Episode 19560 	 avg length: 202 	 reward: 177
# Episode 19580 	 avg length: 205 	 reward: 172
# Episode 19600 	 avg length: 216 	 reward: 162
# Episode 19620 	 avg length: 192 	 reward: 108
# Episode 19640 	 avg length: 212 	 reward: 177
# Episode 19660 	 avg length: 199 	 reward: 158
# Episode 19680 	 avg length: 169 	 reward: 202
# Episode 19700 	 avg length: 187 	 reward: 134
# Episode 19720 	 avg length: 183 	 reward: 153
# Episode 19740 	 avg length: 149 	 reward: 113
# Episode 19760 	 avg length: 194 	 reward: 180
# Episode 19780 	 avg length: 169 	 reward: 173
# Episode 19800 	 avg length: 185 	 reward: 200
# Episode 19820 	 avg length: 175 	 reward: 148
# Episode 19840 	 avg length: 189 	 reward: 179
# Episode 19860 	 avg length: 219 	 reward: 226
# Episode 19880 	 avg length: 204 	 reward: 187
# Episode 19900 	 avg length: 196 	 reward: 198
# Episode 19920 	 avg length: 208 	 reward: 208
# Episode 19940 	 avg length: 186 	 reward: 223
# Episode 19960 	 avg length: 205 	 reward: 203
# Episode 19980 	 avg length: 198 	 reward: 220
# Episode 20000 	 avg length: 198 	 reward: 138
# Episode 20020 	 avg length: 200 	 reward: 191
# Episode 20040 	 avg length: 199 	 reward: 184
# Episode 20060 	 avg length: 191 	 reward: 209
# Episode 20080 	 avg length: 180 	 reward: 207
# Episode 20100 	 avg length: 165 	 reward: 138
# Episode 20120 	 avg length: 162 	 reward: 153
# Episode 20140 	 avg length: 182 	 reward: 149
# Episode 20160 	 avg length: 172 	 reward: 175
# Episode 20180 	 avg length: 180 	 reward: 189
# Episode 20200 	 avg length: 209 	 reward: 201
# Episode 20220 	 avg length: 182 	 reward: 164
# Episode 20240 	 avg length: 212 	 reward: 179
# Episode 20260 	 avg length: 207 	 reward: 201
# ########## Solved! ##########

# %%
 state_dim = env.observation_space.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d7f7f74167e8> in <module>
# ----> 1 state_dim = env.observation_space.shape[0]
#
# NameError: name 'env' is not defined
